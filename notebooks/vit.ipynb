# %%
import os
os.chdir('../')

# %%
os.getcwd()
# Out:
# '/media/nazirnayal/DATA/projects/attention_long_tail/paying-attention-to-the-long-tail'

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import timm
from pprint import pprint
from torchsummary import summary

# %%
pprint(timm.list_models('*swin*'))
# Out:
# ['eca_swinnext26ts_256',
#  'swin_base_patch4_window7_224',
#  'swin_base_patch4_window7_224_in22k',
#  'swin_base_patch4_window12_384',
#  'swin_base_patch4_window12_384_in22k',
#  'swin_large_patch4_window7_224',
#  'swin_large_patch4_window7_224_in22k',
#  'swin_large_patch4_window12_384',
#  'swin_large_patch4_window12_384_in22k',
#  'swin_small_patch4_window7_224',
#  'swin_tiny_patch4_window7_224',
#  'swinnet26t_256',
#  'swinnet50ts_256']

# %%
deit = timm.create_model('deit_base_distilled_patch16_224')

# %%
summary(deit, (3, 224, 224))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─PatchEmbed: 1-1                        [-1, 196, 768]            --
# |    └─Conv2d: 2-1                       [-1, 768, 14, 14]         590,592
# |    └─Identity: 2-2                     [-1, 196, 768]            --
# ├─Dropout: 1-2                           [-1, 198, 768]            --
# ├─Sequential: 1-3                        [-1, 198, 768]            --
# |    └─Block: 2-3                        [-1, 198, 768]            --
# |    |    └─LayerNorm: 3-1               [-1, 198, 768]            1,536
# |    |    └─Attention: 3-2               [-1, 198, 768]            2,362,368
# |    |    └─Identity: 3-3                [-1, 198, 768]            --
# |    |    └─LayerNorm: 3-4               [-1, 198, 768]            1,536
# |    |    └─Mlp: 3-5                     [-1, 198, 768]            4,722,432
# |    |    └─Identity: 3-6                [-1, 198, 768]            --
# ...

# %%
vit = timm.create_model('vit_base_patch16_224')

# %%
summary(vit, (3, 224, 224))
# Out:
# ...
# Layer (type:depth-idx)                   Output Shape              Param #
# ...
# ├─PatchEmbed: 1-1                        [-1, 196, 768]            --
# |    └─Conv2d: 2-1                       [-1, 768, 14, 14]         590,592
# |    └─Identity: 2-2                     [-1, 196, 768]            --
# ├─Dropout: 1-2                           [-1, 197, 768]            --
# ├─Sequential: 1-3                        [-1, 197, 768]            --
# |    └─Block: 2-3                        [-1, 197, 768]            --
# |    |    └─LayerNorm: 3-1               [-1, 197, 768]            1,536
# |    |    └─Attention: 3-2               [-1, 197, 768]            2,362,368
# |    |    └─Identity: 3-3                [-1, 197, 768]            --
# |    |    └─LayerNorm: 3-4               [-1, 197, 768]            1,536
# |    |    └─Mlp: 3-5                     [-1, 197, 768]            4,722,432
# |    |    └─Identity: 3-6                [-1, 197, 768]            --
# ...

# %%
swin = timm.create_model('swin_base_patch4_window7_224')
# Out:
# /home/nazirnayal/anaconda3/envs/nazir_env/lib/python3.8/site-packages/torch/functional.py:445: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2157.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
summary(swin, (3, 224, 224))
# Out:
# ...
# Layer (type:depth-idx)                             Output Shape              Param #
# ...
# ├─PatchEmbed: 1-1                                  [-1, 3136, 128]           --
# |    └─Conv2d: 2-1                                 [-1, 128, 56, 56]         6,272
# |    └─LayerNorm: 2-2                              [-1, 3136, 128]           256
# ├─Dropout: 1-2                                     [-1, 3136, 128]           --
# ├─Sequential: 1-3                                  [-1, 49, 1024]            --
# |    └─BasicLayer: 2-3                             [-1, 784, 256]            --
# |    |    └─PatchMerging: 3-1                      [-1, 784, 256]            132,096
# |    └─BasicLayer: 2-4                             [-1, 196, 512]            --
# |    |    └─PatchMerging: 3-2                      [-1, 196, 512]            526,336
# |    └─BasicLayer: 2-5                             [-1, 49, 1024]            --
# ...
